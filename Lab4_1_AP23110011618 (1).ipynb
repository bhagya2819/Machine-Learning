# %% [markdown]
# <h2 align="center"> Logistic Regression </h2>

# %% [markdown]
# ### Task 2: Load the Data and Libraries
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use("ggplot")
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff4b8f4b-62aa-42f7-bc58-409311a7046f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff4b8f4b-62aa-42f7-bc58-409311a7046f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("DMV_Written_Tests.csv")
df.head()   # shows the first 5 rows
# Out:
#    DMV_Test_1  DMV_Test_2  Results
# 0   34.623660   78.024693        0
# 1   30.286711   43.894998        0
# 2   35.847409   72.902198        0
# 3   60.182599   86.308552        1
# 4   79.032736   75.344376        1

# %% [markdown]
# ### Task 3: Visualize the Data
# ---

# %%
df.info()
df.describe()

sns.histplot(df['DMV_Test_1'], bins=20, kde=True)
plt.title("Distribution of DMV_Test_1")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DMV_Test_1  100 non-null    float64
#  1   DMV_Test_2  100 non-null    float64
#  2   Results     100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
sns.scatterplot(data=df, x="DMV_Test_1", y="DMV_Test_2", hue="Results")
plt.title("DMV Test Scores (Colored by Result)")
plt.show()

# %% [markdown]
# ### Task 4: Define the Logistic Sigmoid Function $\sigma(z)$
# ---
#
# $$ \sigma(z) = \frac{1}{1+e^{-z}}$$

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def predict_proba(W, b, X):
    return sigmoid(X @ W + b)


def log_loss(p, y):
    eps = 1e-12               # avoid log(0)
    p = np.clip(p, eps, 1-eps)
    return -np.mean(y*np.log(p) + (1-y)*np.log(1-p))


def gradients(W, b, X, y):
    p = predict_proba(W, b, X)
    diff = (p - y)              # errors
    dW = (X.T @ diff) / X.shape[0]   # weight gradients
    db = np.mean(diff)               # bias gradient
    return dW, db, p

# %%
# Assume we pick some weights
w0, w1, w2 = -30, 0.2, 0.3   # bias, test1 weight, test2 weight

X1 = df['DMV_Test_1'].values
X2 = df['DMV_Test_2'].values

z = w0 + w1*X1 + w2*X2
probs = sigmoid(z)

print(probs[:10])  # first 10 probabilities
# Out:
# [5.82279924e-01 2.09330874e-05 2.76906459e-01 9.99640014e-01
#  9.99777389e-01 1.64890383e-02 9.99985976e-01 2.63307732e-01
#  9.99989307e-01 4.86648671e-01]

# %% [markdown]
# ### Task 5: Compute the Cost Function $J(\theta)$ and Gradient
# ---

# %% [markdown]
# The objective of logistic regression is to minimize the cost function
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^{m} [ y^{(i)}log(h_{\theta}(x^{(i)})) + (1 - y^{(i)})log(1 - (h_{\theta}(x^{(i)}))]$$
#
# where the gradient of the cost function is given by
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^{m} (h_{\theta}(x^{(i)}) - y^{(i)})x_j^{(i)}$$

# %%
# --- Task 5: Cost Function J(θ) and Gradient ---
# Vectorized implementations

def log_loss(p, y):
    """Binary cross-entropy loss (average).
    p: predicted probabilities, shape (m,) or (m,1)
    y: true labels in {0,1}, shape (m,)
    """
    p = p.reshape(-1)
    y = y.reshape(-1)
    # clip for numerical stability
    eps = 1e-12
    p = np.clip(p, eps, 1 - eps)
    m = y.shape[0]
    return - (1.0/m) * (np.sum(y * np.log(p) + (1 - y) * np.log(1 - p)))

def gradients(W, b, X, y):
    """Compute gradients dW and db and return predictions too.
    W: (n,), b: scalar, X: (m,n), y: (m,)
    """
    m, n = X.shape
    # predictions
    z = X @ W + b
    p = sigmoid(z)
    # residual
    r = (p - y)  # shape (m,)
    # grads
    dW = (1.0/m) * (X.T @ r)  # shape (n,)
    db = (1.0/m) * np.sum(r)
    return dW, db, p

# %%
# Extract features and labels
X = df[['DMV_Test_1', 'DMV_Test_2']].values
y = df['Results'].values.astype(float)

# Initialize parameters
W = np.zeros(X.shape[1])   # (2,)
b = 0.0

# Compute gradients and cost
dW, db, p = gradients(W, b, X, y)
J = log_loss(p, y)

print("Cost J(θ):", J)
print("Gradient dW:", dW)
print("Gradient db:", db)
# Out:
# Cost J(θ): 0.6931471805599453
# Gradient dW: [-12.00921659 -11.26284221]
# Gradient db: -0.1

# %% [markdown]
# ### Task 6: Cost and Gradient at Initialization
# ---

# %%
# --- Task 6: Cost and Gradient at Initialization ---

# Features (X) and labels (y)
X = df[['DMV_Test_1', 'DMV_Test_2']].values.astype(float)
y = df['Results'].values.astype(float)

# Initialize parameters
W = np.zeros(X.shape[1])   # (2,)
b = 0.0

# Compute gradients and cost at initialization
dW, db, p = gradients(W, b, X, y)
J = log_loss(p, y)

print("Initial Cost J(θ=0):", J)
print("Initial Gradient dW:", dW)
print("Initial Gradient db:", db)
# Out:
# Initial Cost J(θ=0): 0.6931471805599453
# Initial Gradient dW: [-12.00921659 -11.26284221]
# Initial Gradient db: -0.1

# %% [markdown]
# ### Task 7: Gradient Descent
# ---

# %% [markdown]
# Minimize the cost function $J(\theta)$ by updating the below equation and repeat until convergence
# $\theta_j := \theta_j - \alpha \frac{\partial J(\theta)}{\partial \theta_j}$ (simultaneously update $\theta_j$ for all $j$)

# %%
# --- Task 7: Gradient Descent ---
def gradient_descent(X, y, lr=0.01, num_iter=2000):
    m, n = X.shape
    W = np.zeros(n)
    b = 0.0
    cost_history = []
    for i in range(num_iter):
        dW, db, p = gradients(W, b, X, y)
        # update
        W -= lr * dW
        b -= lr * db
        # track cost
        if i % 20 == 0 or i == num_iter - 1:
            cost = log_loss(p, y)
            cost_history.append(cost)
    return W, b, cost_history

# Run optimization
opt_W, opt_b, cost_history = gradient_descent(X, y, lr=0.01, num_iter=2000)
print("Optimized W:", opt_W)
print("Optimized b:", opt_b)
# Out:
# Optimized W: [ 0.15986133 -0.31339415]
# Optimized b: -1.5393470018367252

# %%
def gradient_descent(X, y, lr=0.01, num_iter=1000):
    m, n = X.shape
    W = np.zeros((n, 1))  # initialize weights
    b = 0.0               # initialize bias

    cost_history = []

    for i in range(num_iter):
        # 1. Compute gradients and predictions
        dW, db, p = gradients(W, b, X, y)

        # 2. Update parameters
        W -= lr * dW
        b -= lr * db

        # 3. Compute cost for monitoring
        if i % 100 == 0 or i == num_iter-1:   # log every 100 steps
            cost = log_loss(p, y)
            cost_history.append(cost)
            print(f"Iteration {i}, Cost: {cost:.4f}")

    return W, b, cost_history

# %% [markdown]
# ### Task 8: Plotting the Convergence of $J(\theta)$
# ---

# %% [markdown]
# Plot $J(\theta)$ against the number of iterations of gradient descent:

# %%
# --- Task 8: Plotting Convergence of J(θ) ---
import matplotlib.pyplot as plt

plt.figure()
plt.plot(cost_history, linewidth=2)
plt.xlabel("Logged iterations (every 20 steps)")
plt.ylabel("Cost J(θ)")
plt.title("Convergence of Logistic Regression (Gradient Descent)")
plt.show()

# %% [markdown]
# ### Task 9: Plotting the decision boundary
# ---

# %% [markdown]
# $h_\theta(x) = \sigma(z)$, where $\sigma$ is the logistic sigmoid function and $z = \theta^Tx$
#
# When $h_\theta(x) \geq 0.5$ the model predicts class "1":
#
# $\implies \sigma(\theta^Tx) \geq 0.5$
#
# $\implies \theta^Tx \geq 0$ predict class "1"
#
# Hence, $\theta_1 + \theta_2x_2 + \theta_3x_3 = 0$ is the equation for the decision boundary, giving us
#
# $ x_3 = \frac{-(\theta_1+\theta_2x_2)}{\theta_3}$

# %%
# --- Task 9: Plotting the Decision Boundary ---
# Decision boundary is where opt_W[0]*x1 + opt_W[1]*x2 + opt_b = 0
# => x2 = -(opt_b + opt_W[0]*x1) / opt_W[1]

x1_vals = np.linspace(df['DMV_Test_1'].min()-5, df['DMV_Test_1'].max()+5, 200)

if abs(opt_W[1]) < 1e-12:
    print("Vertical boundary (w2≈0); plotting a vertical line.")
    x2_vals = None
else:
    x2_vals = (-(opt_b + opt_W[0]*x1_vals) / opt_W[1])

# Scatter plot of points colored by class
passed = df['Results'] == 1
failed = df['Results'] == 0

plt.figure()
plt.scatter(df.loc[passed, 'DMV_Test_1'], df.loc[passed, 'DMV_Test_2'], label="Pass", alpha=0.7)
plt.scatter(df.loc[failed, 'DMV_Test_1'], df.loc[failed, 'DMV_Test_2'], label="Fail", alpha=0.7)

if x2_vals is None:
    x_line = -opt_b/opt_W[0]
    plt.axvline(x=x_line, linestyle='--', label='Decision boundary')
else:
    plt.plot(x1_vals, x2_vals, linestyle='--', label='Decision boundary')

plt.xlabel("DMV_Test_1")
plt.ylabel("DMV_Test_2")
plt.title("Logistic Regression Decision Boundary")
plt.legend()
plt.show()

# %% [markdown]
# ### Task 10: Predictions using the optimized $\theta$ values
# ---

# %% [markdown]
# $h_\theta(x) = x\theta$

# %%
# --- Task 10: Predictions and Accuracy ---

def predict(X, W, b, threshold=0.5):
    probs = sigmoid(X @ W + b)
    return (probs >= threshold).astype(int)

y_pred = predict(X, opt_W, opt_b, threshold=0.5)

accuracy = (y_pred.reshape(-1) == y.reshape(-1)).mean()
print(f"Training Accuracy: {accuracy*100:.2f}%")

# Optional: confusion matrix
from collections import Counter
tp = np.sum((y_pred==1) & (y==1))
tn = np.sum((y_pred==0) & (y==0))
fp = np.sum((y_pred==1) & (y==0))
fn = np.sum((y_pred==0) & (y==1))
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# Training Accuracy: 37.00%
# TP: 0, TN: 37, FP: 3, FN: 60
